# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarbhadra7/Python-Programs/blob/master/PyCaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pycaret.utils import enable_colab 
enable_colab() 
pycaret_data=pd.read_csv(r'C:\Users\sagar\Downloads\Train_aBjfeNk.csv') 
pycaret_data.drop(['ID'],axis=1,inplace=True)
from pycaret.classification import * 
exp_clf101 = setup(data = pycaret_data, target = 'Segmentation', remove_outliers=True,normalize=True,transformation=True,pca=True,polynomial_features=True,session_id=123)  
compare_models()
# Out:
# <style  type="text/css" >
#     #T_4d498674_d3cb_11ea_9178_7429afebfad4 th {
#           text-align: left;
#     }    #T_4d498674_d3cb_11ea_9178_7429afebfad4row0_col0 {
#             text-align:  left;
#         }    #T_4d498674_d3cb_11ea_9178_7429afebfad4row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_4d498674_d3cb_11ea_9178_7429afebfad4row0_col2 {
#             text-align:  left;
#         }    #T_4d498674_d3cb_11ea_9178_7429afebfad4row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_4d498674_d3cb_11ea_9178_7429afebfad4row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_4d498674_d3cb_11ea_9178_7429afebfad4row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_4d498674_d3cb_11ea_9178_7429afebfad4row0_col6 {
#             background-color:  yellow;
# ...

# %%
xgb = create_model('xgboost')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.5469  0.0  0.5350  0.5337  0.5349  0.3919
# 1       0.5221  0.0  0.5106  0.5042  0.5070  0.3594
# 2       0.5239  0.0  0.5124  0.5117  0.5118  0.3608
# 3       0.5345  0.0  0.5225  0.5180  0.5217  0.3757
# 4       0.5239  0.0  0.5132  0.5148  0.5152  0.3616
# 5       0.5504  0.0  0.5381  0.5384  0.5398  0.3966
# 6       0.5416  0.0  0.5320  0.5375  0.5343  0.3858
# 7       0.5496  0.0  0.5417  0.5432  0.5452  0.3972
# 8       0.5496  0.0  0.5415  0.5434  0.5440  0.3975
# 9       0.5355  0.0  0.5232  0.5232  0.5203  0.3766
# Mean    0.5378  0.0  0.5270  0.5268  0.5274  0.3803
# SD      0.0109  0.0  0.0116  0.0135  0.0132  0.0149

# %%
tuned_adaboost = tune_model('xgboost')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.4973  0.0  0.4864  0.4886  0.4920  0.3270
# 1       0.4973  0.0  0.4898  0.4932  0.4950  0.3279
# 2       0.4832  0.0  0.4734  0.4774  0.4789  0.3080
# 3       0.5009  0.0  0.4918  0.4926  0.4958  0.3321
# 4       0.4743  0.0  0.4647  0.4703  0.4713  0.2966
# 5       0.4726  0.0  0.4615  0.4655  0.4652  0.2925
# 6       0.5115  0.0  0.5027  0.5065  0.5083  0.3463
# 7       0.4947  0.0  0.4865  0.4892  0.4910  0.3240
# 8       0.4787  0.0  0.4727  0.4833  0.4805  0.3041
# 9       0.5142  0.0  0.5059  0.5118  0.5126  0.3504
# Mean    0.4925  0.0  0.4835  0.4878  0.4891  0.3209
# SD      0.0140  0.0  0.0143  0.0138  0.0144  0.0189

# %%
# create a model
xgb = create_model('xgboost')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.5469  0.0  0.5350  0.5337  0.5349  0.3919
# 1       0.5221  0.0  0.5106  0.5042  0.5070  0.3594
# 2       0.5239  0.0  0.5124  0.5117  0.5118  0.3608
# 3       0.5345  0.0  0.5225  0.5180  0.5217  0.3757
# 4       0.5239  0.0  0.5132  0.5148  0.5152  0.3616
# 5       0.5504  0.0  0.5381  0.5384  0.5398  0.3966
# 6       0.5416  0.0  0.5320  0.5375  0.5343  0.3858
# 7       0.5496  0.0  0.5417  0.5432  0.5452  0.3972
# 8       0.5496  0.0  0.5415  0.5434  0.5440  0.3975
# 9       0.5355  0.0  0.5232  0.5232  0.5203  0.3766
# Mean    0.5378  0.0  0.5270  0.5268  0.5274  0.3803
# SD      0.0109  0.0  0.0116  0.0135  0.0132  0.0149

# %%
# AUC plot
plot_model(xgb, plot = 'auc')

# %%
# Decision Boundary
plot_model(xgb, plot = 'confusion')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Value Error): Plot Not Available. Please see docstring for list of available Plots.

# %%
# Precision Recall Curve
plot_model(xgb, plot = 'pr')

# %%
# Validation Curve
plot_model(xgb, plot = 'feature')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Type Error): Feature Importance plot not available for estimators that doesnt support coef_ or feature_importances_ attribute.

# %%
# create a model
xgb = create_model('xgboost')
# summary plot
interpret_model(xgb)
# correlation plot
interpret_model(xgb, plot = 'correlation')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.5469  0.0  0.5350  0.5337  0.5349  0.3919
# 1       0.5221  0.0  0.5106  0.5042  0.5070  0.3594
# 2       0.5239  0.0  0.5124  0.5117  0.5118  0.3608
# 3       0.5345  0.0  0.5225  0.5180  0.5217  0.3757
# 4       0.5239  0.0  0.5132  0.5148  0.5152  0.3616
# 5       0.5504  0.0  0.5381  0.5384  0.5398  0.3966
# 6       0.5416  0.0  0.5320  0.5375  0.5343  0.3858
# 7       0.5496  0.0  0.5417  0.5432  0.5452  0.3972
# 8       0.5496  0.0  0.5415  0.5434  0.5440  0.3975
# 9       0.5355  0.0  0.5232  0.5232  0.5203  0.3766
# Mean    0.5378  0.0  0.5270  0.5268  0.5274  0.3803
# SD      0.0109  0.0  0.0116  0.0135  0.0132  0.0149
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Type Error): This function only supports tree based models for binary classification.

# %%
interpret_model(xgb, plot = 'reason', observation = 0)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Type Error): This function only supports tree based models for binary classification.

# %%
# create a model
xgb = create_model('xgboost')
# predict test / hold-out dataset
xgb_holdout_pred = predict_model(xgb)
# Out:
#                     Model  Accuracy  AUC  Recall  Prec.      F1  Kappa
# 0  One Vs Rest Classifier    0.5266    0  0.5145  0.512  0.5139  0.365

# %%
import multiprocessing
import os
print(multiprocessing.cpu_count())
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# 4
