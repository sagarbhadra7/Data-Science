# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarbhadra7/Python-Programs/blob/master/Stattics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd Downloads/
# Out:
# C:\Users\sagar\Downloads

# %%
df_weather=pd.read_csv('weather.csv')

# %%
df_weather.head()
# Out:
#              Date/Time  Temp (C)  ...  Stn Press (kPa)               Weather
# 0  2012-01-01 00:00:00      -1.8  ...           101.24                   Fog
# 1  2012-01-01 01:00:00      -1.8  ...           101.24                   Fog
# 2  2012-01-01 02:00:00      -1.8  ...           101.26  Freezing Drizzle,Fog
# 3  2012-01-01 03:00:00      -1.5  ...           101.27  Freezing Drizzle,Fog
# 4  2012-01-01 04:00:00      -1.5  ...           101.23                   Fog
#
# [5 rows x 8 columns]

# %%
df_weather.columns
# Out:
# Index(['Date/Time', 'Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)',
#        'Wind Spd (km/h)', 'Visibility (km)', 'Stn Press (kPa)', 'Weather'],
#       dtype='object')

# %%
df_weather.isnull().sum()
# Out:
# Date/Time             0
# Temp (C)              0
# Dew Point Temp (C)    0
# Rel Hum (%)           0
# Wind Spd (km/h)       0
# Visibility (km)       0
# Stn Press (kPa)       0
# Weather               0
# dtype: int64

# %%
weather_Visibility_mean=df_weather['Visibility (km)'].mean()
print(weather_Visibility_mean)
# Out:
# 27.66444672131151

# %%
weather_Visibility_median=df_weather['Visibility (km)'].median()
print(weather_Visibility_median)
# Out:
# 25.0

# %%
Dew Point Temp (C)

# %%
weather_due_point_mean=df_weather['Dew Point Temp (C)'].mean()
print(weather_due_point_mean)
# Out:
# 2.555293715847001

# %%
weather_due_point_median=df_weather['Dew Point Temp (C)'].median()
print(weather_due_point_median)
# Out:
# 3.3

# %%
weather_Weather_mode=df_weather['Weather'].mode()
print(weather_Weather_mode)
# Out:
# 0    Mainly Clear
# dtype: object

# %%
df_weather['Wind Spd (km/h)'].hist()

# %%
df_weather['Temp (C)'].hist()

# %%
plt.subplot(1,2,1)
df_weather['Temp (C)'].hist()
plt.subplot(1,2,2)
df_weather['Wind Spd (km/h)'].hist()
plt.show()

# %%
df_weather.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df_weather['Month']=pd.to_datetime(df_weather['Date/Time']).dt.month

# %%
pd.to_datetime(df_weather['Date/Time']).dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 8779    12
# 8780    12
# 8781    12
# 8782    12
# 8783    12
# Name: Date/Time, Length: 8784, dtype: int64

# %%
df_weather.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog
#
#    Month
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df_weather_due=df_weather.groupby(df_weather['Month'])['Dew Point Temp (C)']

# %%
df_weather_due

# %%
plt.box(df_weather.groupby(df_weather['Month']))

# %%
df_weather.boxplot(column=['Dew Point Temp (C)'],by=['Month'],figsize=(15,15))

# %%
df_weather_due_var=df_weather['Dew Point Temp (C)'].var()
print(df_weather_due_var)
# Out:
# 118.44126310397384

# %%
df_weather_due_std=df_weather['Dew Point Temp (C)'].std()
print(df_weather_due_std)
# Out:
# 10.883072319155737

# %%
df_weather.corr()
# Out:
#                     Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Temp (C)            1.000000            0.932714    -0.220182
# Dew Point Temp (C)  0.932714            1.000000     0.139494
# Rel Hum (%)        -0.220182            0.139494     1.000000
# Wind Spd (km/h)    -0.061876           -0.095685    -0.092743
# Visibility (km)     0.273455            0.050813    -0.633683
# Stn Press (kPa)    -0.236389           -0.320616    -0.231424
# Month               0.218048            0.299641     0.232040
#
#                     Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Temp (C)                  -0.061876         0.273455        -0.236389
# Dew Point Temp (C)        -0.095685         0.050813        -0.320616
# Rel Hum (%)               -0.092743        -0.633683        -0.231424
# Wind Spd (km/h)            1.000000         0.004883        -0.356613
# Visibility (km)            0.004883         1.000000         0.231847
# Stn Press (kPa)           -0.356613         0.231847         1.000000
# Month                     -0.030506        -0.027314         0.070355
#
#                        Month
# Temp (C)            0.218048
# Dew Point Temp (C)  0.299641
# Rel Hum (%)         0.232040
# Wind Spd (km/h)    -0.030506
# Visibility (km)    -0.027314
# Stn Press (kPa)     0.070355
# Month               1.000000

# %%
sns.heatmap(df_weather.corr())

# %%
import pandas_profiling as pp
pp.ProfileReport(df_weather)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>8 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>8784 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>549.1 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>64.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Dew Point Temp (C)"><code>Dew Point Temp (C)</code></a> is highly correlated with <a href="#pp_var_Temp (C)"><code>Temp (C)</code></a> (ρ = 0.93271) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_Wind Spd (km/h)"><code>Wind Spd (km/h)</code></a> has 309 / 3.5% zeros <span class="label label-info">Zeros</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Date/Time">Date/Time<br/>
#             <small>Categorical, Unique</small>
#         </p>
#     </div><div class="col-md-3 collapse in" id="minivalues-1192838291284517057"><table border="1" class="dataframe example_values">
#   <thead>
#     <tr style="text-align: right;">
#       <th>First 3 values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2012-02-24 12:00:00</td>
#     </tr>
#     <tr>
#       <td>2012-08-27 23:00:00</td>
#     </tr>
#     <tr>
#       <td>2012-06-09 10:00:00</td>
#     </tr>
#   </tbody>
# </table></div>
# <div class="col-md-6 collapse in" id="minivalues-1192838291284517057"><table border="1" class="dataframe example_values">
#   <thead>
#     <tr
