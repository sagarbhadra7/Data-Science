# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarbhadra7/Python-Programs/blob/master/HouseSales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
plt.figure(figsize=[14,10])

# %%
cd Downloads/
# Out:
# C:\Users\sagar\Downloads

# %%
df_sales=pd.read_csv('train.csv')

# %%
df_sales.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# ...

# %%
df_sales.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
# ...

# %%
print(df_sales.isnull().sum())
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
df_sales.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold       YrSold      SalePrice
# ...

# %%
import pandas_profiling as pp
pp.ProfileReport(df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-f6e9a4a3a2dd> in <module>
# ----> 1 import pandas_profiling as pp
#       2 pp.ProfileReport(df)
#
# ~\Anaconda3\lib\site-packages\pandas_profiling\__init__.py in <module>
#      10 import pandas_profiling.templates as templates
#      11 from .describe import describe
# ---> 12 from .report import to_html
#      13
#      14 NO_OUTPUTFILE = "pandas_profiling.no_outputfile"
#
# ImportError: cannot import name 'to_html' from 'pandas_profiling.report' (C:\Users\sagar\Anaconda3\lib\site-packages\pandas_profiling\report\__init__.py)

# %%
ax=sns.distplot(df_sales['SalePrice'],hist=False)

# %%
ax=sns.distplot(np.log(df_sales['SalePrice']),hist=False)

# %%
log_sale=np.log(df_sales['SalePrice'])

# %%
sale_skey_befor=df_sales['SalePrice'].skew()

# %%
print(sale_skey_befor)
# Out:
# 1.8828757597682129

# %%
sale_skey_aftr=np.log(df_sales['SalePrice']).skew()

# %%
print(sale_skey_aftr)
# Out:
# 0.12133506220520406

# %%
sale_coor=df_sales.corr()

# %%
sale_corealtion=sale_coor['SalePrice'].sort_values()[::-1]

# %%
sns.barplot(sale_corealtion.index,sale_corealtion)

# %%
plt.figure(figsize=[14,10])
sns.barplot(sale_corealtion.values,sale_corealtion.index)
#plt.xlim()
plt.show()

# %%
df_sales['OverallQual']
# Out:
# 0       7
# 1       6
# 2       7
# 3       7
# 4       8
#        ..
# 1455    6
# 1456    6
# 1457    7
# 1458    5
# 1459    5
# Name: OverallQual, Length: 1460, dtype: int64

# %%
qul_sal=df_sales.groupby(['OverallQual'])['SalePrice'].mean()

# %%
print(qul_sal)
# Out:
# OverallQual
# 1      50150.000000
# 2      51770.333333
# 3      87473.750000
# 4     108420.655172
# 5     133523.347607
# 6     161603.034759
# 7     207716.423197
# 8     274735.535714
# 9     367513.023256
# 10    438588.388889
# Name: SalePrice, dtype: float64

# %%
sns.barplot(qul_sal.index,qul_sal.values)
plt.ylabel('Price')
plt.title('Quality vs Price')
plt.show()

# %%
data = df_sales[["GrLivArea", "SalePrice"]]

# %%
plt.figure(figsize=[14,10])
plt.scatter(data['GrLivArea'],data['SalePrice'])
plt.show()

# %%
log_data=np.log(data)

# %%
plt.figure(figsize=[14,10])
plt.scatter(log_data['GrLivArea'],log_data['SalePrice'])
plt.show()

# %%
data_gar=df_sales[['SalePrice','GarageArea']]
data_gar
# Out:
#       SalePrice  GarageArea
# 0        208500         548
# 1        181500         460
# 2        223500         608
# 3        140000         642
# 4        250000         836
# ...         ...         ...
# 1455     175000         460
# 1456     210000         500
# 1457     266500         252
# 1458     142125         240
# 1459     147500         276
#
# [1460 rows x 2 columns]

# %%
plt.figure(figsize=[14,10])
sns.regplot(data_gar['SalePrice'],data_gar['GarageArea'])
plt.show()

# %%
data_garage=df_sales[df_sales['GarageArea']!=0][['SalePrice','GarageArea']]

# %%
plt.figure(figsize=[14,10])
sns.regplot(data_garage['SalePrice'],data_garage['GarageArea'])
plt.show()

# %%
log_data_garage=np.log(data_garage)

# %%
plt.figure(figsize=[14,10])
sns.regplot(log_data_garage['SalePrice'],log_data_garage['GarageArea'])
plt.show()

# %%
data_garage_less=df_sales[df_sales['GarageArea']==0][['SalePrice','GarageArea']]

# %%
print(data_garage_less)

# %%
data_garage_more=data_garage
data_garage_more['GarageArea']=1

# %%
plt.figure(figsize=[14,10])
data_tmp = pd.DataFrame(columns=["GarageArea", "SalePrice"])
for garage_area, sale_price in df_sales[["GarageArea", "SalePrice"]].values:
    data_tmp = data_tmp.append(pd.DataFrame([[">0" if garage_area > 0 else "=0", sale_price]], columns=data_tmp.columns))
data_tmp["SalePrice"] = data_tmp["SalePrice"].apply(float)
sns.boxplot(x="GarageArea", y="SalePrice", data=data_tmp)
plt.show()

# %%
df2 = df_sales[df_sales['GarageArea']==0]['SalePrice']
df3 = df_sales[df_sales['GarageArea']>0]['SalePrice']
plt.boxplot([df2,df3])
plt.show()

# %%
#Neighborhood       
plt.figure(figsize=[14,14])
sns.boxplot(x="Neighborhood", y="SalePrice", data=df_sales)
#plt.figure(figsize=[14,10])
plt.xticks(rotation=90)
plt.show()

# %%
nulls = pd.DataFrame(df_sales.isnull().sum().sort_values(ascending=False))
nulls.columns = ["Null count"]
nulls["Unique"] = df_sales[nulls.index].nunique()
nulls["dtype"] = df_sales[nulls.index].dtypes
nulls[nulls["Null count"] > 0]
# Out:
#               Null count  Unique    dtype
# PoolQC              1453       3   object
# MiscFeature         1406       4   object
# Alley               1369       2   object
# Fence               1179       4   object
# FireplaceQu          690       5   object
# LotFrontage          259     110  float64
# GarageCond            81       5   object
# GarageType            81       6   object
# GarageYrBlt           81      97  float64
# GarageFinish          81       3   object
# GarageQual            81       5   object
# BsmtExposure          38       4   object
# BsmtFinType2          38       6   object
# BsmtFinType1          37       6   object
# BsmtCond              37       4   object
# BsmtQual              37       4   object
# MasVnrArea             8     327  float64
# MasVnrType             8       4   object
# Electrical             1       5   object

# %%
sale_kurt=df_sales['SalePrice'].kurt()
print(sale_kurt)
# Out:
# 6.536281860064529

# %%
df_sales['YearBuilt']
# Out:
# 0       2003
# 1       1976
# 2       2001
# 3       1915
# 4       2000
#         ...
# 1455    1999
# 1456    1978
# 1457    1941
# 1458    1950
# 1459    1965
# Name: YearBuilt, Length: 1460, dtype: int64

# %%
plt.figure(figsize=[14,14])
sns.boxplot(x="SalePrice", y="YearBuilt", data=df_sales)

#df_sales.boxplot(column=['SalePrice'],by=['YearBuilt'],figsize=(15,15))
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=[20,20])
#sns.boxplot(x="SalePrice", y="YearBuilt", data=df_sales)
df_sales.boxplot(column=['SalePrice'],by=['YearBuilt'],figsize=(15,15))
plt.xticks(rotation=90)
plt.show()

# %%
var = 'YearBuilt'
data = pd.concat([df_sales['SalePrice'], df_sales[var]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=[14,14])
sns.heatmap(df_sales.corr(),vmax=0.5,square=True,annot=True,fmt='.2f')
plt.show()

# %%
#saleprice correlation matrix
k = 10 #number of variables for heatmap
cols = df_sales.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df_sales[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00c33e08c6dc> in <module>()
#       1 #saleprice correlation matrix
#       2 k = 10 #number of variables for heatmap
# ----> 3 cols = df_sales.nlargest(k, 'SalePrice')['SalePrice'].index
#       4 cm = np.corrcoef(df_sales[cols].values.T)
#       5 sns.set(font_scale=1.25)
#
# NameError: name 'df_sales' is not defined

# %%
sns.pairplot(df_sales[['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']])

# %%
sns.pairplot(df_sales[['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']],size=2.5)
# Out:
# C:\Users\sagar\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
nulls = pd.DataFrame(df_sales.isnull().sum().sort_values(ascending=False))
nulls.columns = ["Null count"]
nulls["Unique"] = df_sales[nulls.index].nunique()
nulls["dtype"] = df_sales[nulls.index].dtypes
df_null=pd.DataFrame(nulls[nulls["Null count"] > 0])

# %%
df_null["percentage"]=df_null['Null count']
# Out:
#               Null count  Unique    dtype
# PoolQC              1453       3   object
# MiscFeature         1406       4   object
# Alley               1369       2   object
# Fence               1179       4   object
# FireplaceQu          690       5   object
# LotFrontage          259     110  float64
# GarageCond            81       5   object
# GarageType            81       6   object
# GarageYrBlt           81      97  float64
# GarageFinish          81       3   object
# GarageQual            81       5   object
# BsmtExposure          38       4   object
# BsmtFinType2          38       6   object
# BsmtFinType1          37       6   object
# BsmtCond              37       4   object
# BsmtQual              37       4   object
# MasVnrArea             8     327  float64
# MasVnrType             8       4   object
# Electrical             1       5   object

# %%
#missing data
total = df_sales.isnull().sum().sort_values(ascending=False)
percent = (df_sales.isnull().sum()/df_sales.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageYrBlt      81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtExposure     38  0.026027
# BsmtFinType2     38  0.026027
# BsmtFinType1     37  0.025342
# BsmtCond         37  0.025342
# BsmtQual         37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Utilities         0  0.000000

# %%
#missing data
total = df_sales.isnull().sum().sort_values(ascending=False)
percent = (df_sales.isnull().count()/df_sales.count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total  Percent
# PoolQC         1453    100.0
# MiscFeature    1406    100.0
# Alley          1369    100.0
# Fence          1179    100.0
# FireplaceQu     690    100.0
# LotFrontage     259    100.0
# GarageCond       81    100.0
# GarageType       81    100.0
# GarageYrBlt      81    100.0
# GarageFinish     81    100.0
# GarageQual       81    100.0
# BsmtExposure     38    100.0
# BsmtFinType2     38    100.0
# BsmtFinType1     37    100.0
# BsmtCond         37    100.0
# BsmtQual         37    100.0
# MasVnrArea        8    100.0
# MasVnrType        8    100.0
# Electrical        1    100.0
# Utilities         0    100.0

# %%
df_sales.count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
# Street           1460
# Alley              91
# LotShape         1460
# LandContour      1460
# Utilities        1460
# LotConfig        1460
# LandSlope        1460
# Neighborhood     1460
# Condition1       1460
# Condition2       1460
# BldgType         1460
# HouseStyle       1460
# OverallQual      1460
# OverallCond      1460
# YearBuilt        1460
# YearRemodAdd     1460
# RoofStyle        1460
# RoofMatl         1460
# Exterior1st      1460
# Exterior2nd      1460
# MasVnrType       1452
# MasVnrArea       1452
# ExterQual        1460
# ExterCond        1460
# Foundation       1460
# BsmtQual         1423
# BsmtCond         1423
# BsmtExposure     1422
# BsmtFinType1     1423
# BsmtFinSF1       1460
# BsmtFinType2     1422
# BsmtFinSF2       1460
# BsmtUnfSF        1460
# TotalBsmtSF      1460
# Heating          1460
# HeatingQC        1460
# ...

# %%
df_sales['SalePrice'].hist()

# %%
df_sales['SalePrice'].hist(bins=10)

# %%
df_sales['SalePrice'].hist(bins=15)

# %%
df_sales['SalePrice'].hist(bins=20)
